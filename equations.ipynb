# %% [markdown]
# $$P(x_i)$$
#
# $$\sum\limits_i P(x_i) = 1$$

# %% [markdown]
# $$\int_a^b P(x)dx$$
#
# $$\int_{-\infty}^\infty P(x)dx = 1$$

# %% [markdown]
# $$E[X] = \sum\limits_i x_i P(x_i)$$
#
# $$E[X] = \int_{-\infty}^\infty xP(x)dx$$

# %% [markdown]
# $$\hat\mu = \frac{1}{N}\sum_{a=1}^N x_a$$
#
# $$\hat{\sigma^2} = \frac{1}{N-1}\sum_{a=1}^N(x_a - \hat\mu)^2$$

# %% [markdown]
# $$\textrm{Var}[X] = E[(X-E[X])^2] = \sum\limits_i (x_i - E[X])^2 P(x_i)$$
#
# $$\textrm{Var}[X] = E[(X-E[X])^2] = \int_{-\infty}^\infty (x - E[X])^2 P(x)dx$$

# %% [markdown]
# $$\textrm{StdDev}[X] = \sqrt{E[(X-E[X])^2]} = \sqrt{\sum\limits_i (x_i - E[X])^2 P(x_i)}$$
#
# $$\textrm{StdDev}[X] = \sqrt{E[(X-E[X])^2]} = \sqrt{\int_{-\infty}^\infty (x - E[X])^2 P(x)dx}$$

# %% [markdown]
# $$P(x_i, y_j, ...) \equiv P(\mathbf{r}_i)$$
#
# $$\sum_i P(\mathbf{r}_i) = 1$$
#
# $$P(x, y, ...) \equiv P(\mathbf{r})$$
#
# $$\int P(\mathbf{r}) d\mathbf{r} = 1$$

# %% [markdown]
# $$E[\mathbf{r}] = \sum_i \mathbf{r}_i P(\mathbf{r}_i)$$
#
# $$E[\mathbf{r}] = \int \mathbf{r} P(\mathbf{r}) d\mathbf{r}$$

# %% [markdown]
# $$\textrm{Cov}[X, Y] = \textrm{E}[(X - \textrm{E}[X])(Y - \textrm{E}[Y])]$$

# %% [markdown]
# $$\textrm{Cov}[R_i, R_j] = \textrm{E}[(R_i - \textrm{E}[R_i])(R_j - \textrm{E}[R_j])]$$

# %% [markdown]
# $$\textrm{Corr}[R_i, R_j] = \frac{\textrm{Cov}[R_i, R_j]}{\sqrt{\textrm{Var}[R_i]\textrm{Var}[R_j]}}$$

# %% [markdown]
# $$P(x_i) = \sum\limits_j P(x_i, y_j)$$
#
# $$P(x) = \int_{-\infty}^\infty P(x, y) dy$$

# %% [markdown]
# $$P(y_j)$$

# %% [markdown]
# $$P(y)$$

# %% [markdown]
# $$P(x_i) = \sum\limits_{j, k, ...} P(x_i, y_j, z_k, ...)$$
#
# $$P(x_i, y_j) = \sum\limits_{k, l ...} P(x_i, y_j, z_k, w_l,...)$$
#
# $$P(x) = \int_{-\infty}^\infty P(x, y, z...) dydz...$$
#
# $$P(x, y) = \int_{-\infty}^\infty P(x, y, z, w...) dzdw...$$

# %% [markdown]
# $$P(\{\mathbf{y}\}|\{\mathbf{x}\}, \theta) = $$
#
# $$P(\mathbf{y}_1|\mathbf{x}_1, \theta)P(\mathbf{y}_2|\mathbf{x}_2, \theta)...P(\mathbf{y}_N|\mathbf{x}_N, \theta)$$

# %% [markdown]
# $$\hat{\theta} = \textrm{argmax}_\theta P(\{\mathbf{y}\}|\{\mathbf{x}\}, \theta)$$

# %% [markdown]
# $$P(A, B)$$

# %% [markdown]
# $$\mathbf{y} \sim P(\mathbf{y}|\mathbf{x}; \theta)$$

# %% [markdown]
# $$\mathbf{z} \sim P(\mathbf{z}|\mathbf{x}, \theta)$$
#
# $$\mathbf{y} \sim P(\mathbf{y}|\mathbf{z}, \mathbf{x}, \theta)$$

# %% [markdown]
# $$P(X|Y = 1)$$
#
# $$P(X|Y = 3)$$

# %% [markdown]
# $$\sum_i P(X=x_i|Y) = 1$$
#
# $$\int_{-\infty}^\infty P(X = x|Y) dx = 1$$

# %% [markdown]
# $$\sum_j P(X|Y = y_j) = 1$$
#
# $$\int_{-\infty}^\infty P(X|Y=y) dy = 1$$

# %% [markdown]
# $$E[X_t] = \sum_i X_t P(\mathbf{X} = \mathbf{x}_i)$$

# %% [markdown]
# $$E[f(X)] = \sum\limits_i f(x_i) P(x_i)$$
#
# $$E[f(X)] = \int_{-\infty}^\infty f(x)P(x)dx$$

# %%
np.array([.04,])
# Out:
# 0.21052631578947367

# %% [markdown]
# $$P(X, Y)$$

# %% [markdown]
# $$P(X|Y) \neq P(Y|X)$$

# %% [markdown]
# $$H[X] = -\textrm{E}[\log P(x)] = -\sum_i p(x_i) \log p(x_i)$$

# %% [markdown]
# $$MI[X;Y] = H[X] - \textrm{E}[H[X|Y]] = H[X] - \sum_j H[X|Y=y_j] P(y_j)$$
#
# $$MI[X;Y] = H[Y] - \textrm{E}[H[Y|X]] = H[Y] - \sum_i H[Y|X=x_i] P(x_i)$$

# %%
import numpy as np

# %%
np.random.randint(0, 3, 15)
# Out:
# array([1, 0, 2, 1, 1, 2, 0, 2, 1, 0, 1, 0, 0, 1, 1])

# %%
np.random.binomial(5, .3, 15)
# Out:
# array([2, 1, 2, 1, 1, 3, 2, 3, 3, 2, 2, 1, 1, 1, 1])

# %%
np.random.poisson(4, 15)
# Out:
# array([4, 3, 8, 3, 8, 6, 5, 3, 3, 6, 3, 3, 6, 4, 5])

# %%
np.random.uniform(0, 2, 5)
# Out:
# array([1.98701023, 0.04845459, 0.9392736 , 1.59886672, 0.45133123])

# %%
np.random.normal(0, 1, 5)
# Out:
# array([-0.66785843,  0.79497   ,  0.99729265,  0.33886247, -1.86057321])

# %%
np.random.lognormal(0, 1, 5)
# Out:
# array([3.91357485, 0.74259097, 0.44697754, 2.0137035 , 0.82056715])

# %%
np.random.exponential(5, 5)
# Out:
# array([3.49463289, 5.58620663, 1.53726615, 2.64806311, 4.64358096])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.hist(np.random.normal(0, 1, 1000), bins=30);

# %%
plt.hist(np.random.exponential(5, 1000), bins=30);

# %% [markdown]
# $$P(X_1, X_2, ...|Y_1, Y_2, ...)$$
#
# $$P(X, Y) = P(X|Y)P(Y) = P(Y|X)P(X)$$
#
# $$P(X|Y) = \frac{P(Y|X)P(X)}{P(Y)}$$
#
# $$P(X|Y,Z) = \frac{P(Y|X,Z)P(X|Z)}{P(Y|Z)}$$

# %% [markdown]
# $$P(mouse|r = 7 Hz) = \frac{P(r = 7 Hz|mouse)P(mouse)}{P(r = 7 Hz)} = \frac{0.4(0.01)}{P(r = 7 Hz)}$$

# %% [markdown]
# $$P(r = 7 Hz) = \sum_i P(r = 7 Hz|M = m_i)P(M = m_i) \\
# = P(r=7 Hz|mouse)P(mouse) + P(r=7 Hz|no\: mouse)P(no\: mouse)\\
# = .4(.01) + .05(.99) = .0535$$

# %% [markdown]
# $$P(mouse|r = 7 Hz) = \frac{0.4(0.01)}{0.0535} \approx .075 \ll 0.4$$

# %%
.4*.01 + .05*.99
# Out:
# 0.053500000000000006

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from disp import set_font_size


fig, axs = plt.subplots(2, 1, figsize=(15, 8), tight_layout=True)

x = np.linspace(0, 15, 10000)
s_0 = 1
s_1 = 1
s_2 = 1
s_3 = 2
mu_0 = 5
mu_1 = 10
mu_2 = 7
mu_3 = 7

y_0 = (1/np.sqrt(2*np.pi*s_0**2))*np.exp(-.5*(x-mu_0)**2/s_0**2)
y_1 = (1/np.sqrt(2*np.pi*s_1**2))*np.exp(-.5*(x-mu_1)**2/s_1**2)
y_2 = (1/np.sqrt(2*np.pi*s_2**2))*np.exp(-.5*(x-mu_2)**2/s_2**2)
y_3 = (1/np.sqrt(2*np.pi*s_3**2))*np.exp(-.5*(x-mu_3)**2/s_3**2)

axs[0].plot(x, y_0, color='k', lw=3)
axs[0].plot(x, y_1, color='r', lw=0)
axs[1].plot(x, y_2, color='k', lw=3)
axs[1].plot(x, y_3, color='b', lw=0)


for ax in axs:
    ax.set_xlabel('x')
    ax.set_ylabel('P(x)')
    set_font_size(ax, 24)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from disp import set_font_size


fig, axs = plt.subplots(2, 1, figsize=(15, 8), tight_layout=True)

x = np.linspace(0, 15, 10000)
s_0 = 1
s_1 = 1
s_2 = 1
s_3 = 2
mu_0 = 5
mu_1 = 10
mu_2 = 7
mu_3 = 7

y_0 = (1/np.sqrt(2*np.pi*s_0**2))*np.exp(-.5*(x-mu_0)**2/s_0**2)
y_1 = (1/np.sqrt(2*np.pi*s_1**2))*np.exp(-.5*(x-mu_1)**2/s_1**2)
y_2 = (1/np.sqrt(2*np.pi*s_2**2))*np.exp(-.5*(x-mu_2)**2/s_2**2)
y_3 = (1/np.sqrt(2*np.pi*s_3**2))*np.exp(-.5*(x-mu_3)**2/s_3**2)

axs[0].plot(x, y_0, color='k', lw=3)
axs[0].plot(x, y_1, color='r', lw=3)
axs[1].plot(x, y_2, color='k', lw=3)
axs[1].plot(x, y_3, color='b', lw=3)


for ax in axs:
    ax.set_xlabel('x')
    ax.set_ylabel('P(x)')
    set_font_size(ax, 24)

# %%
# %matplotlib inline
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np

from disp import set_font_size

x = np.random.normal(0, 1, 10000)
y = 2*x + np.random.normal(0, 2, 10000)

gs = gridspec.GridSpec(4, 4)

fig = plt.figure(figsize=(10, 10), tight_layout=True)
axs = [fig.add_subplot(gs[:-1, :-1]), fig.add_subplot(gs[-1, :-1]), fig.add_subplot(gs[:-1, -1])]

axs[0].hist2d(x, y, bins=30, cmap='Greys')
axs[0].set_xlim(-7.5, 7.5)
axs[0].set_ylim(-7.5, 7.5)

axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].xaxis.tick_top()
axs[0].xaxis.set_label_position('top')

cts_x, bins_x = np.histogram(x, bins=50)
bincs_x = .5*(bins_x[:-1] + bins_x[1:])

axs[1].plot(bincs_x, cts_x, lw=3, color='k')
axs[1].set_xlim(-7.5, 7.5)
axs[1].set_yticks([])
axs[1].set_ylabel('P(x)')
axs[1].set_xlabel('x')

cts_y, bins_y = np.histogram(y, bins=50)
bincs_y = .5*(bins_y[:-1] + bins_y[1:])

axs[2].plot(cts_y, bincs_y, lw=3, color='k')
axs[2].set_ylim(-7.5, 7.5)
axs[2].set_ylabel('y')
axs[2].set_xticks([])
axs[2].set_xlabel('P(y)')
axs[2].yaxis.tick_right()
axs[2].yaxis.set_label_position('right')

for ax in axs:
    set_font_size(ax, 30)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from disp import set_font_size


fig, ax = plt.subplots(1, 1, figsize=(15, 4), tight_layout=True)

x = np.linspace(0, 15, 10000)
s_0 = 1
s_1 = 1
mu_0 = 5
mu_1 = 7

y_0 = (1/np.sqrt(2*np.pi*s_0**2))*np.exp(-.5*(x-mu_0)**2/s_0**2)
y_1 = (1/np.sqrt(2*np.pi*s_1**2))*np.exp(-.5*(x-mu_1)**2/s_1**2)

ax.plot(x, y_0, color='k', lw=3)
ax.plot(x, y_1, color='r', lw=3)


ax.set_xlabel('r (Hz)')
ax.set_ylabel('Probability')
ax.legend(['P(r|no mouse)', 'P(r|mouse)'])
set_font_size(ax, 24)
ax.grid()

# %%
y_0[4666]
# Out:
# 0.054023371623602455

# %%
y_1[4666]
# Out:
# 0.39894226244543946

# %% [markdown]
# $$\frac{P(\textrm{mouse}|r = 7 Hz)}{P(\textrm{no mouse}|r = 7 Hz)} < \frac{P(r = 7 Hz|\textrm{mouse})}{P(r = 7 Hz|\textrm{no mouse})}$$

# %% [markdown]
# $$P(k; n, p) = {n \choose k} p^k (1-p)^{n-k}$$

# %% [markdown]
# $$P(k; \lambda) = \frac{\lambda^k e^{-\lambda}}{k!}$$

# %% [markdown]
# $$P(x) = \frac{1}{b-a}$$

# %% [markdown]
# $$P(x) = \frac{1}{\sqrt{2\pi \sigma^2}}\exp\left(-\frac{1}{2}\frac{(x-\mu)^2}{\sigma^2}\right)$$

# %% [markdown]
# $$P(x) = \frac{1}{\beta}\exp\left(\frac{-x}{\beta}\right)$$

# %% [markdown]
# $$X \sim P(X)$$

# %% [markdown]
# $$P(x, y, z) = P(x)P(y)P(z)$$

# %% [markdown]
# $$P(x, y, z) \neq P(x)P(y)P(z)$$

# %% [markdown]
# $$P(X_N, X_{N-1}, ..., X_1) = P(X_N| X_{N-1}, ..., X_1) P(X_{N-1}|X_{N-2}, ..., X_1)...$$
#
# $$...P(X_2|X_1)P(X_1)$$

# %% [markdown]
# $$P(X, Y, Z, W)$$

# %% [markdown]
# $$P(X|Y, Z, W) = \frac{P(Y|X, Z, W)P(X|Z, W)}{P(Y|Z, W)}$$

# %% [markdown]
# $$P(X, W|Z, Y) = \frac{P(Z|X, W, Y)P(X, W|Y)}{P(Z|Y)}$$

# %% [markdown]
# $$P(X) = \sum_j P(X, Y = y_j) = \sum_j P(X|Y=y_j)P(Y=y_j)$$

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(3, 1, figsize=(15, 6), tight_layout=True)

axs[0].plot(np.random.normal(0, 1, 100), lw=2)
axs[1].plot(np.random.normal(0, 1, 100), lw=2)
axs[2].plot(np.random.normal(0, 1, 100), lw=2)

for ax in axs:
    ax.grid()
    set_font_size(ax, 20)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import gaussian_filter1d


fig, ax = plt.subplots(1, 1, figsize=(12, 6), tight_layout=True)

x = np.random.normal(np.arange(10), 4, (5000, 10))
y = gaussian_filter1d(x, 50, 0)

ax.plot(np.arange(5000), y, lw=5)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import gaussian_filter1d as smooth

from disp import set_font_size


fig, axs = plt.subplots(3, 1, figsize=(7, 6), tight_layout=True)

for ax in axs:
    ax.plot(smooth(np.random.normal(0, 1, 1000), 10))
    ax.set_ylim(-.5, .5)
    ax.set_xlabel('Timestep')
    ax.set_ylabel('Current (pA)')
    
    set_font_size(ax, 16)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import gaussian_filter1d as smooth

from disp import set_font_size


fig, axs = plt.subplots(3, 1, figsize=(7, 6), tight_layout=True)

for ax in axs:
    t = np.arange(1000, dtype=float) + np.random.uniform(0, 1000)
    x = np.sin(2*np.pi*t/400)
    x = x + np.random.normal(0, .5, len(x))
    ax.plot(x)
    ax.set_ylim(-2, 2)
    ax.set_xlabel('Timestep')
    ax.set_ylabel('Current (pA)')
    
    set_font_size(ax, 16)

# %%
len(x)
# Out:
# 5000
